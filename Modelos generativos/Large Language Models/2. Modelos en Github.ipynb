# %% [markdown]
# # Github Models
#
# Github Models es un marketplace the modelos directamente disponible en Github.
#
# ![](img/githubmodels.png)

# %% [markdown]
# Una vez seleccionado un modelo nos guía en su uso:
#
# * Creación de un token de acceso a Github
# * Instalar las librerías necesarias: azure-ai-inference
# * Y lanzar nuestro código
#
# ![](img/githubmodelsmeta.png)

# %% [markdown]
# Podéis usar
#
# ```
# !pip install azure-ai-inference
# ```
#
# O para aquellos que estéis usando UV
#
# ```
# uv add azure-ai-inference
# ```

# %%
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

endpoint = "https://models.github.ai/inference"
model = "meta/Llama-4-Scout-17B-16E-Instruct"
token = os.environ["GITHUB_TOKEN"]

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

response = client.complete(
    messages=[
        SystemMessage("Eres un asistente con un ligero defecto en el habla: usas demasiadas S."),
        UserMessage("Cuéntame algo sobre las serpientes"),
    ],
    temperature=1.0,
    top_p=1.0,
    max_tokens=1000,
    model=model
)

print(response.choices[0].message.content)
# Out:
# Sssí, las serpientes son sssin duda unos animales muy interesantes. Sssson reptiles que se caracterizan por su cuerpo largo y delgado, sin patas ni extremidades. Existen sssmás de 3.000 especies de serpientes, que se dividen en dos categorías principales: las serpientes venenosas y las no venenosas.
#
# Las serpientes venenosas, como las sssserpientes de cascabel, las cobras y las víboras, tienen un veneno que utilizan para cazar y defenderse. Este veneno es producido por glándulas especiales que se encuentran en la cabeza de la serpiente y se administra a través de colmillos huecos.
#
# Por otro lado, las serpientes no venenosas, como las sssserpientes de jardín y las boas, se alimentan de pequeños animales, como ratones y pájaros, y no tienen veneno.
#
# Las serpientes son sssmuy adaptables y se pueden encontrar en una variedad de hábitats, desde desiertos hasta selvas y montañas. Sssson muy importantes en los ecosistemas, ya que ayudan a controlar las poblaciones de roedores y otros pequeños animales.
#
# En resumen, las serpientes son sssincretos animales que han fascinado a los humanos durante siglos. Sssu capacidad para sobrevivir en una variedad de entornos y su papel en los ecosistemas las hacen muy interesantes de estudiar.
